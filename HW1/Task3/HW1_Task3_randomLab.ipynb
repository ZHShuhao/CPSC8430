# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from PIL import Image
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
from torchvision import transforms

my_transforms = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])


#random labels
def load_assign_rand_labels(training_size, testing_size):
    trainset = datasets.MNIST('data',
                              train = True,
                              download = True,
                              transform = my_transforms)

    # Assign random labels to the images
    trainset.targets = torch.tensor(np.random.randint(0, 10, (len(trainset)),))
    train_loader = torch.utils.data.DataLoader(trainset, batch_size=training_size, shuffle=True)

    testset = datasets.MNIST('data',
                             train = False,
                             transform = my_transforms)

    test_loader = torch.utils.data.DataLoader(testset ,batch_size = testing_size, shuffle=True)

    return (train_loader, test_loader)

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.c1 = nn.Conv2d(1, 5, 5)
        self.c2 = nn.Conv2d(5, 16, 5)
        self.l1 = nn.Linear(16 * 5 * 5, 100)
        self.l2 = nn.Linear(100, 84)
        self.l3 = nn.Linear(84, 10)
    def forward(self, x):
        x = F.relu(self.c1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.c2(x))
        x = F.max_pool2d(x, 2)

        x = x.view(x.size()[0], -1)
        x = F.relu(self.l1(x))
        x = F.relu(self.l2(x))

        x = self.l3(x)
        return x

# %%
training_size = 100
testing_size = 100
train_loader, test_loader = load_assign_rand_labels(training_size, testing_size)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
def train_func(model, optimizer, train_data):
    model.train()
    correct = 0
    train_loss = 0
    counter = 0

    for batch_idx, (data, target) in enumerate(train_data):
        counter += 1
        data, target = data.to(device), target.to(device)
        #data, target = Variable(data), Variable(target)
        optimizer.zero_grad()

        # Forward propagation
        output = model(data)
        loss = loss_fn(output, target)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

        #pred = np.argmax(output.data, axis=1)
        pred = torch.argmax(output.data, dim=1)
        #correct += np.equal(pred, target.data).sum()
        correct += (pred == target).sum().item()

    train_loss = (train_loss * 100) / len(train_data.dataset)
    accuracy = 100.0 * correct / len(train_data.dataset)
    return train_loss, accuracy

# %%
def test_func(model, epoch, test_data):
    model.eval()
    test_loss = 0
    correct = 0

    for data, target in test_data:
        data, target = data.to(device), target.to(device)
        #data, target = Variable(data), Variable(target)

        output = model(data)
        loss = loss_fn(output, target)
        test_loss += loss.item()

        #pred = np.argmax(output.data, axis = 1)
        pred = torch.argmax(output.data, dim=1)
        #correct = correct + np.equal(pred, target.data).sum()
        correct += (pred == target).sum().item()

    test_loss = (test_loss * 100) / len(test_loader.dataset)
    print('\nTest set, Epoch {} , Average loss: {:.4f}, Accuracy: {:.0f}%\n'.format(epoch, test_loss,
        100. * correct / len(test_data.dataset)))
    return test_loss

# %%
model = Model().to(device)

optimizer = optim.Adam(model.parameters(), lr=0.0001)
train_loss_arr = []
test_loss_arr = []
epoch_arr = []

epochs = 100
# log_interval = 500
loss_fn = torch.nn.CrossEntropyLoss()

for epoch in range(1, epochs + 1):
    model.train()
    print('Training epoch - ', epoch)
    tr_loss, acc = train_func(model, optimizer, train_loader)
    train_loss_arr.append(tr_loss)
    loss_test = test_func(model, epoch, test_loader)
    test_loss_arr.append(loss_test)
    epoch_arr.append(epoch)
# Out:
# Training epoch -  1
#
# Test set, Epoch 1 , Average loss: 2.3007, Accuracy: 12%
#
# Training epoch -  2
#
# Test set, Epoch 2 , Average loss: 2.2998, Accuracy: 10%
#
# Training epoch -  3
#
# Test set, Epoch 3 , Average loss: 2.3002, Accuracy: 10%
#
# Training epoch -  4
#
# Test set, Epoch 4 , Average loss: 2.3055, Accuracy: 8%
#
# Training epoch -  5
#
# Test set, Epoch 5 , Average loss: 2.3046, Accuracy: 7%
#
# Training epoch -  6
#
# Test set, Epoch 6 , Average loss: 2.3088, Accuracy: 9%
#
# Training epoch -  7
#
# Test set, Epoch 7 , Average loss: 2.3090, Accuracy: 9%
#
# Training epoch -  8
#
# Test set, Epoch 8 , Average loss: 2.3075, Accuracy: 9%
#
# Training epoch -  9
#
# Test set, Epoch 9 , Average loss: 2.3039, Accuracy: 10%
#
# Training epoch -  10
#
# Test set, Epoch 10 , Average loss: 2.3093, Accuracy: 9%
#
# Training epoch -  11
#
# Test set, Epoch 11 , Average loss: 2.3107, Accuracy: 8%
#
# Training epoch -  12
#
# Test set, Epoch 12 , Average loss: 2.3129, Accuracy: 7%
#
# Training epoch -  13
#
# Test set, Epoch 13 , Average loss: 2.3175, Accuracy: 7%
#
# Training epoch -  14
#
# Test set, Epoch 14 , Average loss: 2.3230, Accuracy: 8%
#
# Training epoch -  15
#
# Test set, Epoch 15 , Average loss: 2.3204, Accuracy: 9%
#
# Training epoch -  16
#
# Test set, Epoch 16 , Average loss: 2.3287, Accuracy: 8%
#
# Training epoch -  17
#
# Test set, Epoch 17 , Average loss: 2.3227, Accuracy: 7%
#
# Training epoch -  18
#
# Test set, Epoch 18 , Average loss: 2.3256, Accuracy: 8%
#
# Training epoch -  19
#
# Test set, Epoch 19 , Average loss: 2.3199, Accuracy: 8%
#
# Training epoch -  20
#
# Test set, Epoch 20 , Average loss: 2.3306, Accuracy: 7%
#
# Training epoch -  21
#
# Test set, Epoch 21 , Average loss: 2.3393, Accuracy: 7%
#
# Training epoch -  22
#
# Test set, Epoch 22 , Average loss: 2.3393, Accuracy: 7%
#
# Training epoch -  23
#
# Test set, Epoch 23 , Average loss: 2.3356, Accuracy: 9%
#
# Training epoch -  24
#
# Test set, Epoch 24 , Average loss: 2.3375, Accuracy: 9%
#
# Training epoch -  25
#
# Test set, Epoch 25 , Average loss: 2.3671, Accuracy: 6%
#
# Training epoch -  26
#
# Test set, Epoch 26 , Average loss: 2.3489, Accuracy: 9%
#
# Training epoch -  27
#
# Test set, Epoch 27 , Average loss: 2.3455, Accuracy: 8%
#
# Training epoch -  28
#
# Test set, Epoch 28 , Average loss: 2.3580, Accuracy: 8%
#
# Training epoch -  29
#
# Test set, Epoch 29 , Average loss: 2.3664, Accuracy: 8%
#
# Training epoch -  30
#
# Test set, Epoch 30 , Average loss: 2.3693, Accuracy: 8%
#
# Training epoch -  31
#
# Test set, Epoch 31 , Average loss: 2.3597, Accuracy: 9%
#
# Training epoch -  32
#
# Test set, Epoch 32 , Average loss: 2.3887, Accuracy: 7%
#
# Training epoch -  33
#
# Test set, Epoch 33 , Average loss: 2.3817, Accuracy: 8%
#
# Training epoch -  34
#
# Test set, Epoch 34 , Average loss: 2.3443, Accuracy: 10%
#
# Training epoch -  35
#
# Test set, Epoch 35 , Average loss: 2.3600, Accuracy: 9%
#
# Training epoch -  36
#
# Test set, Epoch 36 , Average loss: 2.3719, Accuracy: 10%
#
# Training epoch -  37
#
# Test set, Epoch 37 , Average loss: 2.3886, Accuracy: 8%
#
# Training epoch -  38
#
# Test set, Epoch 38 , Average loss: 2.3740, Accuracy: 9%
#
# Training epoch -  39
#
# Test set, Epoch 39 , Average loss: 2.3791, Accuracy: 9%
#
# Training epoch -  40
#
# Test set, Epoch 40 , Average loss: 2.3962, Accuracy: 9%
#
# Training epoch -  41
#
# Test set, Epoch 41 , Average loss: 2.3836, Accuracy: 10%
#
# Training epoch -  42
#
# Test set, Epoch 42 , Average loss: 2.4025, Accuracy: 9%
#
# Training epoch -  43
#
# Test set, Epoch 43 , Average loss: 2.3882, Accuracy: 9%
#
# Training epoch -  44
#
# Test set, Epoch 44 , Average loss: 2.4037, Accuracy: 9%
#
# Training epoch -  45
#
# Test set, Epoch 45 , Average loss: 2.3972, Accuracy: 9%
#
# Training epoch -  46
#
# Test set, Epoch 46 , Average loss: 2.3811, Accuracy: 11%
#
# Training epoch -  47
#
# Test set, Epoch 47 , Average loss: 2.3885, Accuracy: 10%
#
# Training epoch -  48
#
# Test set, Epoch 48 , Average loss: 2.4150, Accuracy: 9%
#
# Training epoch -  49
#
# Test set, Epoch 49 , Average loss: 2.4350, Accuracy: 8%
#
# Training epoch -  50
#
# Test set, Epoch 50 , Average loss: 2.4095, Accuracy: 9%
#
# Training epoch -  51
#
# Test set, Epoch 51 , Average loss: 2.4313, Accuracy: 9%
#
# Training epoch -  52
#
# Test set, Epoch 52 , Average loss: 2.3971, Accuracy: 10%
#
# Training epoch -  53
#
# Test set, Epoch 53 , Average loss: 2.3813, Accuracy: 11%
#
# Training epoch -  54
#
# Test set, Epoch 54 , Average loss: 2.4236, Accuracy: 9%
#
# Training epoch -  55
#
# Test set, Epoch 55 , Average loss: 2.4755, Accuracy: 8%
#
# Training epoch -  56
#
# Test set, Epoch 56 , Average loss: 2.3885, Accuracy: 11%
#
# Training epoch -  57
#
# Test set, Epoch 57 , Average loss: 2.4316, Accuracy: 10%
#
# Training epoch -  58
#
# Test set, Epoch 58 , Average loss: 2.4791, Accuracy: 8%
#
# Training epoch -  59
#
# Test set, Epoch 59 , Average loss: 2.4608, Accuracy: 9%
#
# Training epoch -  60
#
# Test set, Epoch 60 , Average loss: 2.4282, Accuracy: 10%
#
# Training epoch -  61
#
# Test set, Epoch 61 , Average loss: 2.4815, Accuracy: 9%
#
# Training epoch -  62
#
# Test set, Epoch 62 , Average loss: 2.4694, Accuracy: 9%
#
# Training epoch -  63
#
# Test set, Epoch 63 , Average loss: 2.4369, Accuracy: 10%
#
# Training epoch -  64
#
# Test set, Epoch 64 , Average loss: 2.4373, Accuracy: 10%
#
# Training epoch -  65
#
# Test set, Epoch 65 , Average loss: 2.4552, Accuracy: 10%
#
# Training epoch -  66
#
# Test set, Epoch 66 , Average loss: 2.4589, Accuracy: 10%
#
# Training epoch -  67
#
# Test set, Epoch 67 , Average loss: 2.4862, Accuracy: 9%
#
# Training epoch -  68
#
# Test set, Epoch 68 , Average loss: 2.4355, Accuracy: 12%
#
# Training epoch -  69
#
# Test set, Epoch 69 , Average loss: 2.4598, Accuracy: 9%
#
# Training epoch -  70
#
# Test set, Epoch 70 , Average loss: 2.5096, Accuracy: 9%
#
# Training epoch -  71
#
# Test set, Epoch 71 , Average loss: 2.5082, Accuracy: 9%
#
# Training epoch -  72
#
# Test set, Epoch 72 , Average loss: 2.4952, Accuracy: 9%
#
# Training epoch -  73
#
# Test set, Epoch 73 , Average loss: 2.5040, Accuracy: 10%
#
# Training epoch -  74
#
# Test set, Epoch 74 , Average loss: 2.5166, Accuracy: 10%
#
# Training epoch -  75
#
# Test set, Epoch 75 , Average loss: 2.4989, Accuracy: 10%
#
# Training epoch -  76
#
# Test set, Epoch 76 , Average loss: 2.5312, Accuracy: 9%
#
# Training epoch -  77
#
# Test set, Epoch 77 , Average loss: 2.4681, Accuracy: 11%
#
# Training epoch -  78
#
# Test set, Epoch 78 , Average loss: 2.5061, Accuracy: 10%
#
# Training epoch -  79
#
# Test set, Epoch 79 , Average loss: 2.5227, Accuracy: 9%
#
# Training epoch -  80
#
# Test set, Epoch 80 , Average loss: 2.5116, Accuracy: 10%
#
# Training epoch -  81
#
# Test set, Epoch 81 , Average loss: 2.5288, Accuracy: 10%
#
# Training epoch -  82
#
# Test set, Epoch 82 , Average loss: 2.5214, Accuracy: 9%
#
# Training epoch -  83
#
# Test set, Epoch 83 , Average loss: 2.5037, Accuracy: 11%
#
# Training epoch -  84
#
# Test set, Epoch 84 , Average loss: 2.5474, Accuracy: 9%
#
# Training epoch -  85
#
# Test set, Epoch 85 , Average loss: 2.5355, Accuracy: 9%
#
# Training epoch -  86
#
# Test set, Epoch 86 , Average loss: 2.5411, Accuracy: 9%
#
# Training epoch -  87
#
# Test set, Epoch 87 , Average loss: 2.5559, Accuracy: 9%
#
# Training epoch -  88
#
# Test set, Epoch 88 , Average loss: 2.5451, Accuracy: 11%
#
# Training epoch -  89
#
# Test set, Epoch 89 , Average loss: 2.5475, Accuracy: 10%
#
# Training epoch -  90
#
# Test set, Epoch 90 , Average loss: 2.5927, Accuracy: 9%
#
# Training epoch -  91
#
# Test set, Epoch 91 , Average loss: 2.5045, Accuracy: 11%
#
# Training epoch -  92
#
# Test set, Epoch 92 , Average loss: 2.6103, Accuracy: 8%
#
# Training epoch -  93
#
# Test set, Epoch 93 , Average loss: 2.5711, Accuracy: 10%
#
# Training epoch -  94
#
# Test set, Epoch 94 , Average loss: 2.5631, Accuracy: 10%
#
# Training epoch -  95
#
# Test set, Epoch 95 , Average loss: 2.5229, Accuracy: 11%
#
# Training epoch -  96
#
# Test set, Epoch 96 , Average loss: 2.5719, Accuracy: 10%
#
# Training epoch -  97
#
# Test set, Epoch 97 , Average loss: 2.5850, Accuracy: 9%
#
# Training epoch -  98
#
# Test set, Epoch 98 , Average loss: 2.5706, Accuracy: 10%
#
# Training epoch -  99
#
# Test set, Epoch 99 , Average loss: 2.5337, Accuracy: 12%
#
# Training epoch -  100
#
# Test set, Epoch 100 , Average loss: 2.5610, Accuracy: 10%

# %%
plt.plot(epoch_arr, test_loss_arr, color = "red")
plt.plot(epoch_arr, train_loss_arr, color = "purple")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Test', 'Train'])
plt.show()
